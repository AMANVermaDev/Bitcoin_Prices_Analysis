# %% [markdown]
# <a href="https://colab.research.google.com/github/AMANVermaDev/Bitcoin_Prices_Analysis/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading Dataset

# %%
df = pd.read_csv('/content/FastagFraudDetection.csv')
df.head(10)
# Out:
#    Transaction_ID        Timestamp Vehicle_Type         FastagID TollBoothID  \
# 0               1   1/6/2023 11:20         Bus   FTG-001-ABC-121       A-101
# 1               2   1/7/2023 14:55          Car  FTG-002-XYZ-451       B-102
# 2               3   1/8/2023 18:25   Motorcycle              NaN       D-104
# 3               4    1/9/2023 2:05        Truck  FTG-044-LMN-322       C-103
# 4               5   1/10/2023 6:35          Van  FTG-505-DEF-652       B-102
# 5               6  1/11/2023 10:00        Sedan  FTG-066-GHI-987       A-101
# 6               7  1/12/2023 15:40          SUV  FTG-707-JKL-210       B-102
# 7               8  1/13/2023 20:15         Bus   FTG-088-UVW-543       C-103
# 8               9   1/14/2023 1:55          Car  FTG-909-RST-876       A-101
# 9              10   1/15/2023 7:30   Motorcycle              NaN       D-104
#
#   Lane_Type Vehicle_Dimensions  Transaction_Amount  Amount_paid  \
# ...

# %%
df.describe()
# Out:
#        Transaction_ID  Transaction_Amount  Amount_paid  Vehicle_Speed
# count     5000.000000          5000.00000  5000.000000    5000.000000
# mean      2500.500000           161.06200   141.261000      67.851200
# std       1443.520003           112.44995   106.480996      16.597547
# min          1.000000             0.00000     0.000000      10.000000
# 25%       1250.750000           100.00000    90.000000      54.000000
# 50%       2500.500000           130.00000   120.000000      67.000000
# 75%       3750.250000           290.00000   160.000000      82.000000
# max       5000.000000           350.00000   350.000000     118.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Transaction_ID         5000 non-null   int64
#  1   Timestamp              5000 non-null   object
#  2   Vehicle_Type           5000 non-null   object
#  3   FastagID               4451 non-null   object
#  4   TollBoothID            5000 non-null   object
#  5   Lane_Type              5000 non-null   object
#  6   Vehicle_Dimensions     5000 non-null   object
#  7   Transaction_Amount     5000 non-null   int64
#  8   Amount_paid            5000 non-null   int64
#  9   Geographical_Location  5000 non-null   object
#  10  Vehicle_Speed          5000 non-null   int64
#  11  Vehicle_Plate_Number   5000 non-null   object
#  12  Fraud_indicator        5000 non-null   object
# dtypes: int64(4), object(9)
# memory usage: 507.9+ KB

# %% [markdown]
# Checking for Missing Values

# %%
df.isnull().sum()
# Out:
# Transaction_ID             0
# Timestamp                  0
# Vehicle_Type               0
# FastagID                 549
# TollBoothID                0
# Lane_Type                  0
# Vehicle_Dimensions         0
# Transaction_Amount         0
# Amount_paid                0
# Geographical_Location      0
# Vehicle_Speed              0
# Vehicle_Plate_Number       0
# Fraud_indicator            0
# dtype: int64

# %% [markdown]
# Since Motorcycles do not have fastag id, filling fastagid values as NA when vehicle type is "Motorcycle"

# %%
mask =df['Vehicle_Type']=='Motorcycle'
df.loc[mask,'FastagID'] ='NA'

# %%
df.isnull().sum()
# Out:
# Transaction_ID           0
# Timestamp                0
# Vehicle_Type             0
# FastagID                 0
# TollBoothID              0
# Lane_Type                0
# Vehicle_Dimensions       0
# Transaction_Amount       0
# Amount_paid              0
# Geographical_Location    0
# Vehicle_Speed            0
# Vehicle_Plate_Number     0
# Fraud_indicator          0
# dtype: int64

# %% [markdown]
# Percentage of Fraudalent Transaction

# %%
df['Fraud_indicator'].value_counts(normalize=True)*100
# Out:
# Not Fraud    80.34
# Fraud        19.66
# Name: Fraud_indicator, dtype: float64

# %%
df.corr()
# Out:
# <ipython-input-12-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     Transaction_ID  Transaction_Amount  Amount_paid  \
# Transaction_ID            1.000000           -0.023515     0.044433
# Transaction_Amount       -0.023515            1.000000     0.870078
# Amount_paid               0.044433            0.870078     1.000000
# Vehicle_Speed             0.014378            0.053229     0.039027
#
#                     Vehicle_Speed
# Transaction_ID           0.014378
# Transaction_Amount       0.053229
# Amount_paid              0.039027
# Vehicle_Speed            1.000000

# %% [markdown]
# # **Explorartory Data Analysis**
#
# Univariate Analysis

# %%
#for numerical data
for column in df.columns:
  if df[column].dtype in ['int64','float64']:
    plt.figure(figsize=(4,2))
    sns.histplot(df[column],kde=True)
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel("frequency")
    plt.show()

# %%
df1 = df[['Vehicle_Type', 'TollBoothID', 'Lane_Type', 'Vehicle_Dimensions', 'Fraud_indicator']]

# %%
#for object type column
custom_palette = sns.color_palette("Set2")
for column in df1.columns:
  if df1[column].dtype =='object':
    plt.figure(figsize=(6,3))
    sns.countplot(data=df1,x=column,palette=custom_palette)
    plt.title(f'Countplot of {column}')
    plt.xlabel(column)
    plt.ylabel("Count")
    plt.show()
# Out:
# <ipython-input-15-7d7ff3a719a1>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df1,x=column,palette=custom_palette)
# <ipython-input-15-7d7ff3a719a1>:6: UserWarning: The palette list has more values (8) than needed (7), which may not be intended.
#   sns.countplot(data=df1,x=column,palette=custom_palette)
# <ipython-input-15-7d7ff3a719a1>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df1,x=column,palette=custom_palette)
# <ipython-input-15-7d7ff3a719a1>:6: UserWarning: The palette list has more values (8) than needed (6), which may not be intended.
#   sns.countplot(data=df1,x=column,palette=custom_palette)
# <ipython-input-15-7d7ff3a719a1>:6: FutureWarning:
# ...

# %% [markdown]
# **Bivariate Analysis**

# %%
sns.scatterplot(data=df, x='Transaction_Amount', y='Vehicle_Speed')
plt.title('Scatter plot of Transaction Amount vs Vehicle Speed')
plt.xlabel('Transaction Amount')
plt.ylabel('Vehicle Speed')
plt.show()

# %%
custom_palette = sns.color_palette("Set3")
sns.barplot(data=df, x='Vehicle_Type', y='Transaction_Amount',palette=custom_palette)
plt.title('Average Transaction Amount by Vehicle Type')
plt.xlabel('Vehicle Type')
plt.ylabel('Average Transaction Amount')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-17-5d413e51efa3>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Vehicle_Type', y='Transaction_Amount',palette=custom_palette)
# <ipython-input-17-5d413e51efa3>:2: UserWarning: The palette list has more values (12) than needed (7), which may not be intended.
#   sns.barplot(data=df, x='Vehicle_Type', y='Transaction_Amount',palette=custom_palette)

# %%
custom_palette = sns.color_palette("Set2")
sns.barplot(data=df, x='Lane_Type', y='Transaction_Amount',palette=custom_palette)
plt.title('Average Transaction Amount by Lane Type')
plt.xlabel('Lane Type')
plt.ylabel('Average Transaction Amount')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-18-6d825fa240d7>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Lane_Type', y='Transaction_Amount',palette=custom_palette)
# <ipython-input-18-6d825fa240d7>:2: UserWarning: The palette list has more values (8) than needed (2), which may not be intended.
#   sns.barplot(data=df, x='Lane_Type', y='Transaction_Amount',palette=custom_palette)

# %%
custom_palette = sns.color_palette("Set2")
sns.barplot(data=df, x='Vehicle_Dimensions', y='Amount_paid',palette=custom_palette)
plt.title('Average Amount paid by each Vehicle Type')
plt.xlabel('Vehicle Type')
plt.ylabel('Average Amount paid')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-19-e05c812342b1>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Vehicle_Dimensions', y='Amount_paid',palette=custom_palette)
# <ipython-input-19-e05c812342b1>:2: UserWarning: The palette list has more values (8) than needed (3), which may not be intended.
#   sns.barplot(data=df, x='Vehicle_Dimensions', y='Amount_paid',palette=custom_palette)

# %%
# Aggregate total amount paid by toll booth
total_amount_paid = df.groupby('TollBoothID')['Amount_paid'].sum().reset_index()

#bar plot
custom_palette = sns.color_palette("Set2")
sns.barplot(data=total_amount_paid, x='TollBoothID', y='Amount_paid',palette=custom_palette)
plt.title('Total Amount collected at Each Toll Booth')
plt.xlabel('Toll Booth ID')
plt.ylabel('Total Amount Paid')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-20-7a6ae4a1f762>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=total_amount_paid, x='TollBoothID', y='Amount_paid',palette=custom_palette)
# <ipython-input-20-7a6ae4a1f762>:6: UserWarning: The palette list has more values (8) than needed (6), which may not be intended.
#   sns.barplot(data=total_amount_paid, x='TollBoothID', y='Amount_paid',palette=custom_palette)

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Vehicle_Type', hue='Fraud_indicator')
plt.title('Vehicle Type vs Fraud Indicator')
plt.xlabel('Vehicle Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Fraud Indicator')
plt.show()

# %% [markdown]
# **Outlier Detection**

# %%
int_columns = df.select_dtypes(include=['int','float']).columns

# Plot boxplots for each integer column
for column in int_columns:
    plt.figure(figsize=(6, 4))
    df.boxplot(column=column)
    plt.title(f"Boxplot of {column}")
    plt.ylabel("Values")
    plt.show()

# %% [markdown]
# ## **Conclusion**
# Our DataFrame fields "**Amount Paid**" and "**Vehicle Speed**" have outliers

# %% [markdown]
# **Outlier Treatement**

# %%
def treat_outliers(df, method='iqr', threshold=1.5):

    numeric_columns = df.select_dtypes(include=['int', 'float']).columns

    for col in numeric_columns:
        if method == 'iqr':
            Q1 = df[col].quantile(0.25)
            Q3 = df[col].quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - threshold * IQR
            upper_bound = Q3 + threshold * IQR
            df[col] = df[col].apply(lambda x: lower_bound if x < lower_bound else upper_bound if x > upper_bound else x)

    return df


df1 = treat_outliers(df) #df1 have no outliers now

# %%
int_columns = df1.select_dtypes(include=['int','float']).columns

for column in int_columns:
    plt.figure(figsize=(6,4))
    df.boxplot(column=column)
    plt.title(f"Boxplot of {column}")
    plt.ylabel("Values")
    plt.show()

# %% [markdown]
# Scaling Numerical Features

# %%
from sklearn.preprocessing import MinMaxScaler

numeric_columns = df1.select_dtypes(include=['int', 'float']).columns

# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Apply Min-Max Scaling to selected columns
df1[numeric_columns] = scaler.fit_transform(df1[numeric_columns])

# %% [markdown]
# Label Encoding Object type features

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

for column in df1.columns:
    if df1[column].dtype == 'object':
        df1[column] = label_encoder.fit_transform(df1[column])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Transaction_ID         5000 non-null   float64
#  1   Timestamp              5000 non-null   int64
#  2   Vehicle_Type           5000 non-null   int64
#  3   FastagID               5000 non-null   int64
#  4   TollBoothID            5000 non-null   int64
#  5   Lane_Type              5000 non-null   int64
#  6   Vehicle_Dimensions     5000 non-null   int64
#  7   Transaction_Amount     5000 non-null   float64
#  8   Amount_paid            5000 non-null   float64
#  9   Geographical_Location  5000 non-null   int64
#  10  Vehicle_Speed          5000 non-null   float64
#  11  Vehicle_Plate_Number   5000 non-null   int64
#  12  Fraud_indicator        5000 non-null   int64
# dtypes: float64(4), int64(9)
# memory usage: 507.9 KB

# %% [markdown]
# Checking Correlation between Features

# %%
Corr = df1.corr()

plt.figure(figsize=(9, 8))
corr_vis = sns.heatmap(Corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # Conclusion :
#
# Removing below columns as they have least correlation with Target
#
#
# *   Vehicle_Speed
# *   Vehicle_Plate_Number
# *   Geographical_Location
# *   Timestamp
# *   Vehicle_Type

# %%
columns_to_remove = ['Vehicle_Speed', 'Vehicle_Plate_Number', 'Geographical_Location', 'Timestamp', 'Vehicle_Type']

df1 = df1.drop(columns=columns_to_remove)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Transaction_ID      5000 non-null   float64
#  1   FastagID            5000 non-null   int64
#  2   TollBoothID         5000 non-null   int64
#  3   Lane_Type           5000 non-null   int64
#  4   Vehicle_Dimensions  5000 non-null   int64
#  5   Transaction_Amount  5000 non-null   float64
#  6   Amount_paid         5000 non-null   float64
#  7   Fraud_indicator     5000 non-null   int64
# dtypes: float64(3), int64(5)
# memory usage: 312.6 KB

# %% [markdown]
# Preparing data for train test Split

# %%
x = df1.drop(['Fraud_indicator'], axis=1)
y = df1['Fraud_indicator']

# %%
#train test split

from sklearn.model_selection import train_test_split
(x_train, x_test, y_train, y_test) = train_test_split(x, y, train_size = 0.85)

# %%
x_test
# Out:
#       Transaction_ID  FastagID  TollBoothID  Lane_Type  Vehicle_Dimensions  \
# 4454        0.890978      2521            0          0                   2
# 4661        0.932386       787            0          1                   1
# 4005        0.801160      1014            2          1                   0
# 1815        0.363073      4286            5          1                   2
# 1303        0.260652       175            0          1                   2
# ...              ...       ...          ...        ...                 ...
# 4880        0.976195      1979            2          0                   0
# 3589        0.717944      4172            1          1                   1
# 1518        0.303661      1750            1          0                   0
# 4740        0.948190      1405            2          0                   0
# 2004        0.400880      4286            5          1                   2
#
#       Transaction_Amount  Amount_paid
# ...

# %%
#using logistic regression

from sklearn.linear_model import LogisticRegression
logisticRegr = LogisticRegression()
logisticRegr.fit(x_train, y_train)
score = logisticRegr.score(x_test, y_test)
print(score)
# Out:
# 0.94
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
